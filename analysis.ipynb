# %%
import os

import numpy as np
import matplotlib.pyplot as plt

import files as io
import nitime as nt
import nitime.analysis as nta

data_files = ['mrs_P71680.7']#, 'mrs_P76288.7', 'pure_gaba_P64024.7']
data_dir = '/Users/arokem/projects/MRS/data/'

# %%
for file_name in data_files:
    data = io.get_data(os.path.join(data_dir, file_name))
    data = data.squeeze()
    # Average over repeats.
    data = np.mean(data, 1)
    ft = np.fft.fft(data)

# %%
ft.shape
# Out:
# (4096, 2, 8)

# %%
figure()
plot(np.abs(data[:, 0, :]))
figure()
plot(np.real(data[:, 0, :]))
figure()
plot(np.imag(data[:, 0, :]))
figure()
plot(np.abs(ft[:, 0, :]))
# Out:
# [<matplotlib.lines.Line2D at 0x10aa980d0>,
#  <matplotlib.lines.Line2D at 0x10aa87150>,
#  <matplotlib.lines.Line2D at 0x10aa84550>,
#  <matplotlib.lines.Line2D at 0x10aa81050>,
#  <matplotlib.lines.Line2D at 0x10aa3ed10>,
#  <matplotlib.lines.Line2D at 0x10aa3e2d0>,
#  <matplotlib.lines.Line2D at 0x10aa3b250>,
#  <matplotlib.lines.Line2D at 0x10aa3b9d0>]

# %%
np.abs(ft).shape
# Out:
# (4096, 2, 8)

# %%
cc = np.abs(ft[:, 2]) #np.mean(np.abs(ft), -1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-a436f38ef0f9> in <module>()
# ----> 1 cc = np.abs(ft[:, 2]) #np.mean(np.abs(ft), -1)
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
plot(cc[:, 0] - cc[:, 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2d35021f3e43> in <module>()
# ----> 1 plot(cc[:, 0] - cc[:, 1])
#
# NameError: name 'cc' is not defined
